# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('matches.csv')

# %%
dataset.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
dataset
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7        8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8        9    2017           Pune  2017-04-11             Delhi Daredevils
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017        Kolkata  2017-04-13              Kings XI Punjab
# ...

# %%
dataset.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
dataset.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
dataset[100:150]
# Out:
#       id  season            city        date                        team1  \
# 100  101    2008          Jaipur  2008-05-17             Rajasthan Royals
# 101  102    2008       Hyderabad  2008-05-18               Mumbai Indians
# 102  103    2008         Kolkata  2008-05-18        Kolkata Knight Riders
# 103  104    2008       Bangalore  2008-05-19  Royal Challengers Bangalore
# 104  105    2008         Kolkata  2008-05-20        Kolkata Knight Riders
# 105  106    2008          Mumbai  2008-05-21              Kings XI Punjab
# 106  107    2008         Chennai  2008-05-21  Royal Challengers Bangalore
# 107  108    2008      Chandigarh  2008-05-23              Deccan Chargers
# 108  109    2008           Delhi  2008-05-24               Mumbai Indians
# 109  110    2008         Chennai  2008-05-24             Rajasthan Royals
# 110  111    2008       Bangalore  2008-05-03  Royal Challengers Bangalore
# 111  112    2008         Kolkata  2008-05-25              Kings XI Punjab
# ...

# %%
dataset["result"]
# Out:
# 0         normal
# 1         normal
# 2         normal
# 3         normal
# 4         normal
# 5         normal
# 6         normal
# 7         normal
# 8         normal
# 9         normal
# 10        normal
# 11        normal
# 12        normal
# 13        normal
# 14        normal
# 15        normal
# 16        normal
# 17        normal
# 18        normal
# 19        normal
# 20        normal
# 21        normal
# 22        normal
# 23        normal
# 24        normal
# 25        normal
# 26        normal
# 27        normal
# 28        normal
# 29        normal
#          ...
# 726       normal
# 727       normal
# 728       normal
# 729       normal
# 730       normal
# 731       normal
# 732       normal
# 733       normal
# 734       normal
# 735       normal
# 736       normal
# 737       normal
# 738       normal
# 739       normal
# 740       normal
# 741       normal
# 742       normal
# 743       normal
# 744    no result
# 745       normal
# 746          tie
# ...

# %%
pd.value_counts(dataset["result"])
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
dataset.shape
# Out:
# (756, 18)

# %%
dataset2 = pd.read_csv("deliveries.csv")

# %%
dataset2.shape
# Out:
# (179078, 21)

# %%
dataset2.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
dataset2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#find number of matches played in each season
pd.value_counts(dataset["season"])
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
#find number of matches every team has won
pd.value_counts(dataset["winner"])
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
#find winner of each season
# dataset["winner"]
temp_df = dataset.drop_duplicates("season", keep = 'last')
temp_df[["season", "winner"]]
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 695    2018    Chennai Super Kings
# 755    2019         Mumbai Indians

# %%
#find players who have won most man_of_the_match awards

# %%
#find matches where csk won
temp_df = dataset["winner"] == "Chennai Super Kings"
dataset[temp_df]
# Out:
#         id  season            city        date                        team1  \
# 60      61    2008      Chandigarh  2008-04-19          Chennai Super Kings
# 66      67    2008         Chennai  2008-04-23          Chennai Super Kings
# 70      71    2008         Chennai  2008-04-26        Kolkata Knight Riders
# 73      74    2008       Bangalore  2008-04-28          Chennai Super Kings
# 86      87    2008           Delhi  2008-05-08             Delhi Daredevils
# 90      91    2008         Chennai  2008-05-10          Chennai Super Kings
# 102    103    2008         Kolkata  2008-05-18        Kolkata Knight Riders
# 113    114    2008       Hyderabad  2008-05-27              Deccan Chargers
# 115    116    2008          Mumbai  2008-05-31              Kings XI Punjab
# 121    122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 136    137    2009       Centurion  2009-04-30          Chennai Super Kings
# ...

# %%
dataset[dataset["winner"] == "Chennai Super Kings"]
# Out:
#         id  season            city        date                        team1  \
# 60      61    2008      Chandigarh  2008-04-19          Chennai Super Kings
# 66      67    2008         Chennai  2008-04-23          Chennai Super Kings
# 70      71    2008         Chennai  2008-04-26        Kolkata Knight Riders
# 73      74    2008       Bangalore  2008-04-28          Chennai Super Kings
# 86      87    2008           Delhi  2008-05-08             Delhi Daredevils
# 90      91    2008         Chennai  2008-05-10          Chennai Super Kings
# 102    103    2008         Kolkata  2008-05-18        Kolkata Knight Riders
# 113    114    2008       Hyderabad  2008-05-27              Deccan Chargers
# 115    116    2008          Mumbai  2008-05-31              Kings XI Punjab
# 121    122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 136    137    2009       Centurion  2009-04-30          Chennai Super Kings
# ...

# %%
temp_df = dataset[(dataset["winner"] == "Chennai Super Kings") &
                  (dataset["win_by_runs"] >= 50)]

# %%
temp_df[["winner", "win_by_runs", "team2"]]
# Out:
#                   winner  win_by_runs                        team2
# 121  Chennai Super Kings           92  Royal Challengers Bangalore
# 143  Chennai Super Kings           78              Deccan Chargers
# 181  Chennai Super Kings           55        Kolkata Knight Riders
# 284  Chennai Super Kings           63             Rajasthan Royals
# 306  Chennai Super Kings           58  Royal Challengers Bangalore
# 312  Chennai Super Kings           74              Deccan Chargers
# 379  Chennai Super Kings           86             Delhi Daredevils
# 403  Chennai Super Kings           86             Delhi Daredevils
# 434  Chennai Super Kings           77          Sunrisers Hyderabad
# 464  Chennai Super Kings           93             Delhi Daredevils
# 541  Chennai Super Kings           97              Kings XI Punjab
# 652  Chennai Super Kings           64             Rajasthan Royals
# 745  Chennai Super Kings           80               Delhi Capitals

# %%
dataset[(dataset["winner"] == "Chennai Super Kings") &
(dataset["win_by_runs"] >= 50)][["winner", "win_by_runs", "team2"]]
# Out:
#                   winner  win_by_runs                        team2
# 121  Chennai Super Kings           92  Royal Challengers Bangalore
# 143  Chennai Super Kings           78              Deccan Chargers
# 181  Chennai Super Kings           55        Kolkata Knight Riders
# 284  Chennai Super Kings           63             Rajasthan Royals
# 306  Chennai Super Kings           58  Royal Challengers Bangalore
# 312  Chennai Super Kings           74              Deccan Chargers
# 379  Chennai Super Kings           86             Delhi Daredevils
# 403  Chennai Super Kings           86             Delhi Daredevils
# 434  Chennai Super Kings           77          Sunrisers Hyderabad
# 464  Chennai Super Kings           93             Delhi Daredevils
# 541  Chennai Super Kings           97              Kings XI Punjab
# 652  Chennai Super Kings           64             Rajasthan Royals
# 745  Chennai Super Kings           80               Delhi Capitals

# %%
dataset2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#find the top 5 players who has taken most number of catches
dataset2[["fielder", "dismissal_kind"]].dropna()
# Out:
#                 fielder dismissal_kind
# 11        Mandeep Singh         caught
# 64          Sachin Baby         caught
# 94          Sachin Baby         caught
# 165           DA Warner         caught
# 199         BCJ Cutting        run out
# 206        Yuvraj Singh         caught
# 211        MC Henriques         caught
# 230        Yuvraj Singh         caught
# 234        MC Henriques         caught
# 242           DA Warner         caught
# 247     CJ Jordan (sub)        run out
# 330            MS Dhoni         caught
# 343            R Bhatia         caught
# 361          MA Agarwal         caught
# 371            MS Dhoni        run out
# 392           RG Sharma         caught
# 434              N Rana         caught
# 467          TG Southee         caught
# 514           YK Pathan         caught
# 557       Kuldeep Yadav         caught
# 615       Kuldeep Yadav         caught
# 750          MP Stoinis         caught
# 762             M Vohra         caught
# ...

# %%
#find top 5 players who have taken most no of wickets

# %%
temp_df = dataset2[["bowler", "dismissal_kind"]].dropna()
temp_df = temp_df[(temp_df["dismissal_kind"] != "run out") &
            (temp_df["dismissal_kind"] != "retired hurt")]
pd.value_counts(temp_df["bowler"]).head()
# Out:
# SL Malinga         170
# A Mishra           156
# Harbhajan Singh    150
# PP Chawla          149
# DJ Bravo           147
# Name: bowler, dtype: int64

# %%
toss_dec = pd.value_counts(dataset["toss_decision"])

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(toss_dec, labels=["field", "bat"], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11a5f1550>,
# ...
#  [Text(-0.3805142883934777, 1.032089567977705, 'field'),
#   Text(0.3805142883934778, -1.032089567977705, 'bat')],
#  [Text(-0.20755324821462415, 0.5629579461696571, '61.24%'),
#   Text(0.20755324821462423, -0.5629579461696571, '38.76%')])

# %%
# plt.style.use('fivethirtyeight')
plt.pie(toss_dec, labels=["field", "bat"], autopct='%.2f%%', startangle=120, counterclock=False, colors=["yellow", "chartreuse"], radius=1.5, pctdistance=1.2, labeldistance=0.4, explode=[0.1,0], shadow=True, rotatelabels=True)
plt.legend()

# %%
temp_df = dataset2[(dataset2["dismissal_kind"] != "retired hurt") &
            (dataset2["dismissal_kind"] != "obstructing the field") & 
                   (dataset2["dismissal_kind"] != "hit wicket")]

# %%
dk = pd.value_counts(temp_df["dismissal_kind"], sort=False)

# %%
dk
# Out:
# caught and bowled     211
# stumped               278
# run out               852
# bowled               1581
# lbw                   540
# caught               5348
# Name: dismissal_kind, dtype: int64

# %%
labels = dk.index

# %%
# plt.style.use('ggplot')
plt.pie(dk, radius=1.5, autopct='%.2f%%', startangle=90, 
        counterclock=False, explode=[0.1,0,0,0,0,0.3]
       ,shadow=True, labels=labels, rotatelabels=True
       ,pctdistance=0.8)
# plt.legend(labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x11a6d16d8>,
# ...
#  [Text(0.13154811273826952, 1.7450487368652488, 'caught and bowled'),
#   Text(0.4076022306166111, 1.5988622272092, 'stumped'),
#   Text(1.0019260264995629, 1.3109707233278696, 'run out'),
#   Text(1.6478851183261256, 0.08351429098838094, 'bowled'),
#   Text(1.2559109231643377, -1.0701344556066312, 'lbw'),
#   Text(-1.840785693889561, -0.6434345570231118, 'caught')],
#  [Text(0.09772145517700022, 1.2963219188141848, '2.40%'),
#   Text(0.2964379859029899, 1.1628088925157818, '3.16%'),
#   Text(0.7286734738178638, 0.9534332533293598, '9.67%'),
#   Text(1.1984619042371822, 0.060737666173367955, '17.95%'),
#   Text(0.9133897623013366, -0.77827960407755, '6.13%'),
#   Text(-1.4159889952996623, -0.49494965924854756, '60.70%')])

# %%
#Histogram - a frequency plot
#It only has X axis
#It works on bins(intervals)
# plt.style.use('ggplot')
# plt.style.use('dark_background')
plt.style.use('fivethirtyeight')
plt.hist(dataset["season"], rwidth=0.9, bins=12)
# plt.plot(pd.value_counts(dataset["season"]))
# Out:
# (array([58., 57., 60., 73., 74., 76., 60., 59., 60., 59., 60., 60.]),
#  array([2008.        , 2008.91666667, 2009.83333333, 2010.75      ,
#         2011.66666667, 2012.58333333, 2013.5       , 2014.41666667,
#         2015.33333333, 2016.25      , 2017.16666667, 2018.08333333,
#         2019.        ]),
#  <a list of 12 Patch objects>)

# %%
plt.figure(figsize=(8,5))
plt.hist(dataset["season"], rwidth=0.8, bins=12, density=True, color="red")
# Out:
# (array([0.08369408, 0.08225108, 0.08658009, 0.10533911, 0.10678211,
#         0.10966811, 0.08658009, 0.08513709, 0.08658009, 0.08513709,
#         0.08658009, 0.08658009]),
#  array([2008.        , 2008.91666667, 2009.83333333, 2010.75      ,
#         2011.66666667, 2012.58333333, 2013.5       , 2014.41666667,
#         2015.33333333, 2016.25      , 2017.16666667, 2018.08333333,
#         2019.        ]),
#  <a list of 12 Patch objects>)

# %%
plt.figure(figsize=(8,5))
plt.hist(dataset["season"], rwidth=0.8, bins=12, density=True, color="#8E44AD")
# Out:
# (array([0.08369408, 0.08225108, 0.08658009, 0.10533911, 0.10678211,
#         0.10966811, 0.08658009, 0.08513709, 0.08658009, 0.08513709,
#         0.08658009, 0.08658009]),
#  array([2008.        , 2008.91666667, 2009.83333333, 2010.75      ,
#         2011.66666667, 2012.58333333, 2013.5       , 2014.41666667,
#         2015.33333333, 2016.25      , 2017.16666667, 2018.08333333,
#         2019.        ]),
#  <a list of 12 Patch objects>)

# %%
pd.unique(dataset["season"].sort_values())
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019])

# %%
index = pd.unique(dataset["season"].sort_values(ascending=True))
data = [10,20,30,40,50,60,70,65,55,45,35,25]

# %%
plt.figure(figsize=(8,5))
plt.hist(dataset["season"], rwidth=0.8, bins=12, color="#8E44AD", histtype="step")
plt.scatter(index,data)

# %%
temp_df = dataset2[dataset2["batsman_runs"] != dataset2["total_runs"]]

# %%
# plt.figure(figsize=(8,7))
plt.plot(range(1,21), temp_df["batsman_runs"][:20])
plt.plot(range(1,21), temp_df["total_runs"][:20])
plt.legend(("batsman_runs", "total_runs"))

# %%
pd.value_counts(dataset2["dismissal_kind"])
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
pd.value_counts(dataset2["dismissal_kind"]).index
# Out:
# Index(['caught', 'bowled', 'run out', 'lbw', 'stumped', 'caught and bowled',
#        'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype='object')

# %%
caught = dataset2[dataset2["dismissal_kind"] == "caught"]
bowled = dataset2[dataset2["dismissal_kind"] == "bowled"]

# %%
caught
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# 211            1       2  Royal Challengers Bangalore
# 230            1       2  Royal Challengers Bangalore
# 234            1       2  Royal Challengers Bangalore
# 242            1       2  Royal Challengers Bangalore
# 330            2       1               Mumbai Indians
# 343            2       1               Mumbai Indians
# 361            2       1               Mumbai Indians
# 392            2       2       Rising Pune Supergiant
# 434            2       2       Rising Pune Supergiant
# 467            2       2       Rising Pune Supergiant
# 514            3       1                Gujarat Lions
# ...

# %%
caught_grouping = caught.groupby("batting_team")["dismissal_kind"].value_counts()
bowled_grouping = bowled.groupby("batting_team")["dismissal_kind"].value_counts()

# %%
caught_grouping
# Out:
# batting_team                 dismissal_kind
# Chennai Super Kings          caught            531
# Deccan Chargers              caught            285
# Delhi Capitals               caught             69
# Delhi Daredevils             caught            581
# Gujarat Lions                caught            103
# Kings XI Punjab              caught            669
# Kochi Tuskers Kerala         caught             44
# Kolkata Knight Riders        caught            618
# Mumbai Indians               caught            690
# Pune Warriors                caught            163
# Rajasthan Royals             caught            508
# Rising Pune Supergiant       caught             48
# Rising Pune Supergiants      caught             39
# Royal Challengers Bangalore  caught            620
# Sunrisers Hyderabad          caught            380
# Name: dismissal_kind, dtype: int64

# %%
bowled_grouping
# Out:
# batting_team                 dismissal_kind
# Chennai Super Kings          bowled            131
# Deccan Chargers              bowled             91
# Delhi Capitals               bowled             19
# Delhi Daredevils             bowled            173
# Gujarat Lions                bowled             41
# Kings XI Punjab              bowled            187
# Kochi Tuskers Kerala         bowled             20
# Kolkata Knight Riders        bowled            168
# Mumbai Indians               bowled            178
# Pune Warriors                bowled             65
# Rajasthan Royals             bowled            165
# Rising Pune Supergiant       bowled             19
# Rising Pune Supergiants      bowled             10
# Royal Challengers Bangalore  bowled            210
# Sunrisers Hyderabad          bowled            104
# Name: dismissal_kind, dtype: int64

# %%
arr.index.levels[0]
# Out:
# Index(['Chennai Super Kings', 'Deccan Chargers', 'Delhi Capitals',
#        'Delhi Daredevils', 'Gujarat Lions', 'Kings XI Punjab',
#        'Kochi Tuskers Kerala', 'Kolkata Knight Riders', 'Mumbai Indians',
#        'Pune Warriors', 'Rajasthan Royals', 'Rising Pune Supergiant',
#        'Rising Pune Supergiants', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad'],
#       dtype='object', name='batting_team')

# %%
team_names = arr.index.levels[0]

# %%
plt.figure(figsize=(10,7))
plt.bar(team_names, caught_grouping, color="blue")
plt.bar(team_names, bowled_grouping, color="orange", bottom=caught_grouping)
plt.ylabel("Dismissal Count")
plt.xlabel("Teams")
plt.xticks(rotation=90)
plt.legend(("caught", "bowled"))

# %%
caught.groupby("batting_team")["dismissal_kind"].value_counts().plot.bar()
bowled.groupby("batting_team")["dismissal_kind"].value_counts().plot.bar()

# %%
plt.hist(dataset[(dataset["season"] != 2019) & (dataset["season"] != 2018)]["season"], rwidth=0.7)
# Out:
# (array([58., 57., 60., 73., 74., 76., 60., 59., 60., 59.]),
#  array([2008. , 2008.9, 2009.8, 2010.7, 2011.6, 2012.5, 2013.4, 2014.3,
#         2015.2, 2016.1, 2017. ]),
#  <a list of 10 Patch objects>)

# %%
pd.value_counts(dataset[(dataset["season"] != 2019) & (dataset["season"] != 2018)]["season"])
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
#To plot frequency without using ranges or intervals, 
#we can use countplot
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.countplot(dataset["season"], saturation=0.9)

# %%
plt.figure(figsize=(8,5))
sns.countplot(dataset["season"], palette='autumn')

# %%
plt.figure(figsize=(2,4))
sns.countplot(dataset["toss_decision"], color="chartreuse", orient='v')

# %%
plt.figure(figsize=(10,7))
plt.style.use('fivethirtyeight')
sns.countplot(dataset["season"], hue=dataset["toss_decision"], hue_order=["bat", "field"])

# %%
plt.figure(figsize=(10,7))
plt.style.use('fivethirtyeight')
sns.countplot(y = dataset["season"], hue=dataset["toss_decision"], hue_order=["bat", "field"])

# %%
winner_count = dataset["winner"].value_counts()

# %%
winner_count
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
winner_count.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Delhi Capitals', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
dataset["winner"].value_counts().plot()

# %%
dataset["winner"].value_counts().plot().bar(winner_count.index, winner_count)
# Out:
# <BarContainer object of 15 artists>

# %%
dataset["winner"].value_counts().plot.bar()

# %%
plt.figure(figsize=(10,8))
dataset["winner"].value_counts().plot.bar()

# %%
plt.figure(figsize=(10,8))
dataset["winner"].value_counts().plot.bar(width=0.8)

# %%
plt.figure(figsize=(10,8))
dataset["winner"].value_counts().plot.bar(width=0.8, color=sns.color_palette('infern', 15))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/envs/new/lib/python3.7/site-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat)
#     231                 # Perhaps a named matplotlib colormap?
# --> 232                 palette = mpl_palette(palette, n_colors)
#     233             except ValueError:
#
# /anaconda3/envs/new/lib/python3.7/site-packages/seaborn/palettes.py in mpl_palette(name, n_colors)
#     455     else:
# --> 456         cmap = mpl.cm.get_cmap(name)
#     457         if cmap is None:
#
# /anaconda3/envs/new/lib/python3.7/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     182             "Colormap %s is not recognized. Possible values are: %s"
# --> 183             % (name, ', '.join(sorted(cmap_d))))
#     184
#
# ...

# %%
plt.figure(figsize=(10,8))
dataset["winner"].value_counts().plot.bar(width=0.8, color=sns.color_palette('inferno'))

# %%
plt.figure(figsize=(10,8))
dataset["winner"].value_counts().plot.bar(width=0.8, color=sns.color_palette('inferno', 15))

# %%
plt.figure(figsize=(10,8))
ax = dataset["winner"].value_counts().plot.bar(width=0.8, color=sns.color_palette('inferno', 15))
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x() + 0.2, p.get_height() + 2))
