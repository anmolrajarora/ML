# %%
#matplotlib/seaborn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.random.randint(10,1000,50)

# %%
y = np.random.randint(10,1000,50)

# %%
x,y
# Out:
# (array([552, 514, 918,  60,  50, 806, 380, 492, 935, 950, 297, 835, 621,
#         308, 311, 935,  59, 624, 285, 166, 666, 217, 660, 546, 308,  78,
#         158, 305,  92, 330, 375, 901, 808, 404, 911, 547, 978, 177, 462,
#         427, 130, 510, 918, 880, 887, 719, 100, 917, 445, 371]),
#  array([326, 685, 723, 258, 814, 613, 439, 142, 585, 585, 624, 152, 144,
#          18, 405, 886, 502, 867, 430,  62,  14,  42, 108, 927, 426, 427,
#         934, 834, 820, 366, 744, 897, 105, 541, 506, 551, 552, 597, 110,
#         806, 596, 491, 243, 385, 680, 250, 691, 336, 730, 787]))

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
X = np.random.randint(10,1000,50)

# %%
y = X ** 2

# %%
X
# Out:
# array([448, 585, 167, 712, 817, 258, 483, 126, 911, 512, 245, 248,  46,
#        845, 663, 640, 942, 992, 780, 526, 538, 856, 613,  53, 488, 381,
#        509, 756, 675, 835, 470, 882, 245, 939, 887, 609,  13, 508, 268,
#        780, 151, 688, 807, 200,  45, 485, 129, 565, 762, 529])

# %%
y
# Out:
# array([200704, 342225,  27889, 506944, 667489,  66564, 233289,  15876,
#        829921, 262144,  60025,  61504,   2116, 714025, 439569, 409600,
#        887364, 984064, 608400, 276676, 289444, 732736, 375769,   2809,
#        238144, 145161, 259081, 571536, 455625, 697225, 220900, 777924,
#         60025, 881721, 786769, 370881,    169, 258064,  71824, 608400,
#         22801, 473344, 651249,  40000,   2025, 235225,  16641, 319225,
#        580644, 279841])

# %%
plt.plot(X,y)

# %%
plt.plot(X,y,'o')

# %%
X = np.random.randint(-1000,1000,50)
y = X ** 2

# %%
plt.plot(X,y,'o')

# %%
X = np.random.randint(-100,100,50)
y = X **3

# %%
plt.plot(X,y,'o')

# %%
X = np.linspace(-100,100)
y = X ** 3

# %%
plt.plot(X,y,'o')

# %%
plt.plot(X,y)

# %%
y = X ** 2

# %%
plt.plot(X,y,'o')

# %%
plt.plot(X,y,'ro',markersize=2)

# %%
plt.plot(X,y,'yo')

# %%
plt.plot(X,y)

# %%
plt.plot(X,y,'r',linewidth=3,linestyle="dashed")

# %%
plt.plot(x, y, 'go--', linewidth=2, markersize=7)

# %%
X = np.linspace(-100,100,50)
X2 = np.linspace(-25,25,50)
y = X ** 2
y2 = X2 ** 3

# %%
plt.plot(X,y,'o')
plt.plot(X2,y2)

# %%
apple_dataset = pd.read_csv("AAPL.csv")

# %%
apple_dataset.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.407747  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.386473   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.358108   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366972   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.377609   18362400.0

# %%
apple_dataset.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9818  2019-11-19  267.899994  268.000000  265.390015  266.290009  266.290009
# 9819  2019-11-20  265.540009  266.079987  260.399994  263.190002  263.190002
# 9820  2019-11-21  263.690002  264.010010  261.179993  262.010010  262.010010
# 9821  2019-11-22  262.589996  263.179993  260.839996  261.779999  261.779999
# 9822  2019-11-25  262.709991  266.440002  262.519989  266.369995  266.369995
#
#           Volume
# 9818  19041800.0
# 9819  26558600.0
# 9820  30348800.0
# 9821  16331300.0
# 9822  21005100.0

# %%
plt.plot(apple_dataset["Adj Close"])

# %%
temp_df = apple_dataset[apple_dataset["Date"] >= "2005-01-01"]

# %%
temp_df.head()
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 6072  2005-01-03  4.627143  4.650714  4.471428  4.520714   3.933478
# 6073  2005-01-04  4.556428  4.676429  4.497857  4.567143   3.973876
# 6074  2005-01-05  4.604286  4.660714  4.575000  4.607143   4.008680
# 6075  2005-01-06  4.619286  4.636428  4.523571  4.610714   4.011787
# 6076  2005-01-07  4.642857  4.973571  4.625000  4.946429   4.303892
#
#            Volume
# 6072  172998000.0
# 6073  274202600.0
# 6074  170108400.0
# 6075  176388800.0
# 6076  556862600.0

# %%
plt.plot(temp_df["Adj Close"])
plt.title("Apple Stock Graph")
plt.xlabel("No. of rows")
plt.ylabel("Share Price")
# plt.bar(temp_df.shape[0], height=temp_df["Open"])
# Out:
# Text(0, 0.5, 'Share Price')

# %%
temp_df.shape
# Out:
# (3751, 7)

# %%
X = pd.to_datetime(temp_df["Date"])

# %%
plt.plot(X, temp_df["Adj Close"])
# Out:
# /anaconda3/envs/new/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
