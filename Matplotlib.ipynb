# %%
#matplotlib/seaborn
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(10,1000,50)

# %%
y = np.random.randint(10,1000,50)

# %%
x,y
# Out:
# (array([209, 204, 736,  73, 866, 128, 596, 858, 563, 254, 789, 409,  47,
#         663, 930, 434, 711, 862, 868, 609,  69, 101, 196, 375, 617, 483,
#         793,  48, 272, 923, 159, 702, 144, 105, 964, 551, 622, 812, 216,
#          25, 107, 672, 922, 401, 222, 145,  91, 668, 687, 666]),
#  array([ 45, 800, 153, 749, 567, 155, 331,  85, 656, 970,  16, 961, 512,
#         932, 164,  65, 745, 520, 459,  51, 117, 378, 750, 448,  28, 876,
#         366, 405, 550, 969, 841, 293, 383, 502, 780, 190, 439, 181, 774,
#         158,  42,  12, 828, 521, 472,  28, 591, 370, 494, 626]))

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)
