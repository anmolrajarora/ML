# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("SaratogaHouses.csv")

# %%
data.shape
# Out:
# (1728, 17)

# %%
data.drop('Unnamed', axis = 1, inplace=True)

# %%
data.head(50)
# Out:
#      price  lotSize  age  landValue  livingArea  pctCollege  bedrooms  \
# 0   132500     0.09   42      50000         906          35         2
# 1   181115     0.92    0      22300        1953          51         3
# 2   109000     0.19  133       7300        1944          51         4
# 3   155000     0.41   13      18700        1944          51         3
# 4    86060     0.11    0      15000         840          51         2
# 5   120000     0.68   31      14000        1152          22         4
# 6   153000     0.40   33      23300        2752          51         4
# 7   170000     1.21   23      14600        1662          35         4
# 8    90000     0.83   36      22200        1632          51         3
# 9   122900     1.94    4      21200        1416          44         3
# 10  325000     2.29  123      12600        2894          51         7
# 11  120000     0.92    1      22300        1624          51         3
# 12   85860     8.97   13       4800         704          41         2
# 13   97000     0.11  153       3100        1383          57         3
# 14  127000     0.14    9        300        1300          41         3
# 15   89900     0.00   88       2500         936          57         3
# 16  155000     0.13    9        300        1300          41         3
# 17  253750     2.00    0      49800        2816          71         4
# 18   60000     0.21   82       8500         924          35         2
# 19   87500     0.88   17      19400        1092          35         3
# 20  112000     1.00   12       8600        1056          35         3
# 21  104900     0.43   21       5600        1600          39         3
# 22  148635     0.32    1       6200        1576          39         3
# 23  150000     0.03   24       5100        2080          39         3
# 24   90400     0.36   16       5200        1600          39         3
# 25  248800     4.00   28       5500        2224          39         4
# 26  135000     1.83  126       6000        1656          39         3
# 27  145000     3.00   26       4500        1170          39         4
# 28  457000     0.43   53       2700        2461          39         4
# 29  140000     0.44   56      19400        1544          71         3
# 30  130000     1.24   51      24800        1220          71         2
# 31  187000     0.46    3      15200        1858          52         3
# 32  229000     0.87    9      41100        2219          64         3
# 33  227000     1.80  201      25500        1876          52         3
# 34  179900     0.46    1      15200        2026          52         4
# 35  169900     0.91   19      20200        1671          71         4
# 36  209900     0.46    1      15200        2060          52         4
# 37  169900     0.59    0      17300        1884          52         4
# 38  293000     7.24   43      36600        2022          71         4
# 39  245900     0.19    0      20700        2394          71         4
# 40  157000     0.46   45      20200        1390          71         3
# 41  195000     0.41   32      27100        1954          71         4
# 42  150000     0.78   54      24500        1554          71         3
# 43  234900     0.89    9      41600        1976          64         3
# 44  279550     1.34    0      44400        2479          71         4
# 45  246500     1.00    0      17100        2714          71         4
# 46  124000     1.00   98      15500         797          52         2
# 47  138000     0.27   54       8900        1500          71         3
# 48  290000     0.71   73      61000        1838          71         4
# 49  108000     0.90   48      19000        1042          71         2
#
#     fireplaces  bathrooms  rooms          heating      fuel  \
# 0            1        1.0      5         electric  electric
# 1            0        2.5      6  hot water/steam       gas
# 2            1        1.0      8  hot water/steam       gas
# 3            1        1.5      5          hot air       gas
# 4            0        1.0      3          hot air       gas
# 5            1        1.0      8          hot air       gas
# 6            1        1.5      8  hot water/steam       oil
# 7            1        1.5      9          hot air       oil
# 8            0        1.5      8         electric  electric
# 9            0        1.5      6          hot air       gas
# 10           0        1.0     12          hot air       oil
# 11           0        2.0      6          hot air       gas
# 12           0        1.0      4         electric  electric
# 13           0        2.0      5  hot water/steam       gas
# 14           0        1.5      8          hot air       oil
# 15           0        1.0      4  hot water/steam       gas
# 16           0        1.5      7          hot air       oil
# 17           1        2.5     12          hot air       gas
# 18           0        1.0      6  hot water/steam       oil
# 19           0        1.0      6          hot air       oil
# 20           0        1.0      7         electric  electric
# 21           0        1.5      4         electric  electric
# 22           0        2.5      7          hot air       gas
# 23           0        2.0      6          hot air       oil
# 24           0        1.5      4         electric  electric
# 25           0        3.0     10          hot air       oil
# 26           0        1.0      6  hot water/steam       oil
# 27           0        1.5      5          hot air       oil
# 28           1        2.0     10          hot air       oil
# 29           1        1.5      7          hot air       oil
# 30           2        1.0      4  hot water/steam       oil
# 31           1        2.5      7          hot air       gas
# 32           1        2.0      8          hot air       gas
# 33           0        2.5      5          hot air       oil
# 34           1        2.5      6          hot air       gas
# 35           1        3.0      8          hot air       gas
# 36           1        2.5      7          hot air       gas
# 37           1        2.5      9          hot air       gas
# 38           2        3.0      6  hot water/steam       gas
# 39           1        2.5      7          hot air       gas
# 40           1        1.5      6          hot air       gas
# 41           0        2.5      8          hot air       gas
# 42           1        1.5      5          hot air       oil
# 43           0        2.5      6          hot air       gas
# 44           1        2.5     10          hot air       gas
# 45           1        2.5      9          hot air       gas
# 46           0        1.0      3          hot air       oil
# 47           0        2.5      7  hot water/steam       gas
# 48           0        2.0      8          hot air       oil
# 49           1        2.0      3          hot air       gas
#
#                 sewer waterfront newConstruction centralAir
# 0              septic         No              No         No
# 1              septic         No              No         No
# 2   public/commercial         No              No         No
# 3              septic         No              No         No
# 4   public/commercial         No             Yes        Yes
# 5              septic         No              No         No
# 6              septic         No              No         No
# 7              septic         No              No         No
# 8              septic         No              No         No
# 9                none         No              No         No
# 10             septic         No              No         No
# 11             septic         No              No         No
# 12             septic         No              No         No
# 13  public/commercial         No              No         No
# 14             septic         No              No         No
# 15  public/commercial         No              No         No
# 16             septic         No              No         No
# 17               none         No              No        Yes
# 18             septic         No              No         No
# 19             septic         No              No         No
# 20             septic         No              No         No
# 21  public/commercial         No              No         No
# 22             septic         No             Yes        Yes
# 23             septic         No              No         No
# 24  public/commercial         No              No         No
# 25             septic         No              No         No
# 26             septic         No              No         No
# 27             septic         No              No         No
# 28  public/commercial        Yes              No         No
# 29             septic         No              No        Yes
# 30             septic         No              No         No
# 31             septic         No              No         No
# 32  public/commercial         No              No         No
# 33             septic         No              No         No
# 34             septic         No              No         No
# 35             septic         No              No        Yes
# 36               none         No              No         No
# 37             septic         No              No         No
# 38             septic         No              No         No
# 39               none         No              No        Yes
# 40             septic         No              No         No
# 41             septic         No              No        Yes
# 42             septic         No              No        Yes
# 43  public/commercial         No              No        Yes
# 44             septic         No              No         No
# 45               none         No              No         No
# 46             septic         No              No         No
# 47             septic         No              No         No
# 48             septic        Yes              No         No
# 49             septic         No              No         No

# %%
plt.scatter(data["livingArea"], data["price"])

# %%
plt.boxplot(data["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11b944748>,
#   <matplotlib.lines.Line2D at 0x11b944e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x11b944d30>,
#   <matplotlib.lines.Line2D at 0x11b842eb8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11b944400>],
#  'medians': [<matplotlib.lines.Line2D at 0x11b8426d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11b939400>],
#  'means': []}

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
axes3d = Axes3D(fig)
X = data["livingArea"]
Y = data["landValue"]
Z = data["price"]
axes3d.scatter(X,Y,Z)
